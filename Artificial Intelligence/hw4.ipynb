# %% [markdown]
# ## Learning Objectives
#
# *   Deep Learning
# *   Computer Vision - Convolutional Neural Network
# *   Natural Language Processing - Recurrent Neural Network

# %% [markdown]
# ## General Information
#
# The base structure and comments are provided on what should be done. You are free to use any code from online sources, but please cite the source properly. Also, you are supposed to create/train the DL model and not use pre-trained models.
#
# **TIPS** while working on this assignment:
#
#
# *   You will have to keep on updating the model to improve accuracy. Hence, all except the first step (loading the data) would be repeated multiple times. i.e. repeat -- model creation, training & testing.
# *   Training a Deep Learning model on real-world datasets and obtain decent accuracy is time consuming. For this assignment, it may take at least 40-60 min, if not more, to train the complete data and get around 35% testing accuracy. Hence, have enough time planned out for finishing the assignment.
# *   Because of the large training time, it is impossisble to train each student's model. Hence, you will be required to **save the weights** in a file. These weights can then be loaded for testing purposes. More information is provided in a TensorFlow tutorial [here](https://www.tensorflow.org/tutorials/keras/save_and_load).
# *   Please refer to the [TensorFlow Keras API](https://www.tensorflow.org/api_docs/python/tf/keras) for selecting the *'activation function', 'loss', 'optimizer' & 'metrics'*. At least use 'accuracy' as one of the 'metrics'.

# %% [markdown]
# ##Import Libraries
#
# Write all the import statements here.

# %%
# importing all required libraries
import tensorflow as tf
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Computer Vision - CNN
#
# The goal of this task is to get hands-on experience in developing, training and testing **Convolutional Neural Network** for the Computer Vision task of Object/Image Classification.

# %% [markdown]
# ## Load/Prepare Data
#
# (20 points)
#
# In this assignment, will work with the well-known **CIFAR-100 dataset**. The dataset consists of 60000 32x32 color images, which belong to 100 classes, with 600 images per class. There are 50000 training images (500 per class) and 10000 test images (100 per class). The 100 classes in the dataset are grouped into 20 superclasses. Each image comes with a "fine" label (the class to which it belongs) and a "coarse" label (the superclass to which it belongs). More information about the dataset can be found [here](https://www.cs.toronto.edu/~kriz/cifar.html). Please visit this [website](https://benchmarks.ai/cifar-100) for the benchmark performances of different techniques on the CIFAR-100 dataset.
#
# In this section, you will write code for the following:
#
# *   Load the CIFAR-100 dataset
# *   Prepare the data to be used for the DL model creation and training
# *   Visualize the data by plotting 100 random images, one each for the 100 classes

# %%
# Load the data - training as well as testing
(train_images, train_labels), (test_images, test_labels) = keras.datasets.cifar100.load_data(label_mode='fine')

# Prepare the data that can be used by the next step - creating and training the DL model
train_images = train_images / 255.0
test_images = test_images / 255.0

# The data from TensforFlow and Keras will only have integer class labels. Each of those 100 integer class labels correspond to the following names, in the correct order
fine_labels = ['apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly', 'camel', 'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur', 'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster', 'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree', 'plain', 'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail', 'snake', 'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout', 'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm']

# These are the string labels for the 20 superclasses. You may not need to use this at all, just provided here for reference.
coarse_labels = ['aquatic_mammals', 'fish', 'flowers', 'food_containers', 'fruit_and_vegetables', 'household_electrical_devices', 'household_furniture', 'insects', 'large_carnivores', 'large_man-made_outdoor_things', 'large_natural_outdoor_scenes', 'large_omnivores_and_herbivores', 'medium_mammals', 'non-insect_invertebrates', 'people', 'reptiles', 'small_mammals', 'trees', 'vehicles_1', 'vehicles_2']
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step

# %%
# Visualize the data by plotting 100 random images, one each for the 100 classes
# Draw 10 images in one row, 10 rows total
plt.figure(figsize=(20, 20))
for i in range(100):
    plt.subplot(10, 10, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(train_images[i])
    plt.xlabel(fine_labels[train_labels[i][0]])
plt.show()

# %% [markdown]
# ## CNN Model Creation
#
# (15 points)
#
# In this section, you will write code for the following:
#
# *   Create a DL model for Computer Vision - Convolutional Neural Network (Use *TensorFlow* and *keras*, as shown in the example code in the lecture for 'deep-learning')
# *   Print the DL model summary

# %%
# Create a DL model for Computer Vision - Convolutional Neural Network (Use *TensorFlow* and *keras*, as shown in the example code in the lecture for 'deep-learning')
def create_model():
    model = keras.Sequential([
                                keras.layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=(32,32,3)),
                                keras.layers.MaxPooling2D(pool_size=(2,2)),
                                keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu'),
                                keras.layers.MaxPooling2D(pool_size=(2,2)),
                                keras.layers.Flatten(),
                                keras.layers.Dense(100, activation='relu'),
                                keras.layers.Dense(len(np.unique(train_labels)), activation='softmax'),
                                ])
    model.compile(
        optimizer='SGD',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
        )
    return model

model = create_model()
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Print the DL model summary
print(model.summary())
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding_4 (Embedding)              │ (None, 200, 128)            │       1,280,000 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_5 (Bidirectional)      │ (None, 200, 256)            │         263,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_6 (Bidirectional)      │ (None, 128)                 │         164,352 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_11 (Dense)                     │ (None, 46)                  │           5,934 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 5,140,364 (19.61 MB)
#  Trainable params: 1,713,454 (6.54 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 3,426,910 (13.07 MB)
# None

# %% [markdown]
# ## Training
#
# (15 points)
#
# In this section, you will write code to do the following:
#
# *   Train/fit the DL model using the training CIFAR-100 data
# *   Plot the training/validation accuracy and loss
# *   *Save the trained model weights* in a folder in the google drive at at location "/content/drive/My Drive/Colab Notebooks/cifar/", to be used for the testing phase

# %%
# Set the model checkpoints to be saved in a folder in the google drive at at location "/content/drive/My Drive/Colab Notebooks/cifar/"
cp_callback = keras.callbacks.ModelCheckpoint(filepath="/content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5",
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
# Train/fit the DL model using the training CIFAR-100 data
history = model.fit(
    train_images, train_labels,
    epochs=50,
    batch_size=50,
    validation_data=(test_images, test_labels),
    callbacks=[cp_callback]
)
# Out:
# Epoch 1/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.0141 - loss: 4.5979
# Epoch 1: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 82s 81ms/step - accuracy: 0.0141 - loss: 4.5979 - val_accuracy: 0.0352 - val_loss: 4.5224
# Epoch 2/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.0409 - loss: 4.4354
# Epoch 2: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 83s 83ms/step - accuracy: 0.0409 - loss: 4.4353 - val_accuracy: 0.0686 - val_loss: 4.1638
# Epoch 3/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.0756 - loss: 4.1101
# Epoch 3: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 140s 82ms/step - accuracy: 0.0756 - loss: 4.1101 - val_accuracy: 0.0942 - val_loss: 3.9941
# Epoch 4/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.1039 - loss: 3.9346
# Epoch 4: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 85s 85ms/step - accuracy: 0.1039 - loss: 3.9345 - val_accuracy: 0.1209 - val_loss: 3.8418
# Epoch 5/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.1308 - loss: 3.7762
# Epoch 5: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 93s 93ms/step - accuracy: 0.1308 - loss: 3.7761 - val_accuracy: 0.1507 - val_loss: 3.6980
# Epoch 6/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.1546 - loss: 3.6499
# Epoch 6: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 130s 81ms/step - accuracy: 0.1546 - loss: 3.6498 - val_accuracy: 0.1696 - val_loss: 3.5899
# Epoch 7/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.1815 - loss: 3.5172
# Epoch 7: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 84s 84ms/step - accuracy: 0.1815 - loss: 3.5172 - val_accuracy: 0.1925 - val_loss: 3.4691
# Epoch 8/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.2010 - loss: 3.4042
# Epoch 8: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 141s 83ms/step - accuracy: 0.2010 - loss: 3.4042 - val_accuracy: 0.2089 - val_loss: 3.3659
# Epoch 9/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.2198 - loss: 3.2991
# Epoch 9: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 144s 85ms/step - accuracy: 0.2198 - loss: 3.2990 - val_accuracy: 0.2267 - val_loss: 3.2873
# Epoch 10/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.2373 - loss: 3.1902
# Epoch 10: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 83s 83ms/step - accuracy: 0.2373 - loss: 3.1902 - val_accuracy: 0.2438 - val_loss: 3.1915
# Epoch 11/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.2553 - loss: 3.0977
# Epoch 11: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 142s 83ms/step - accuracy: 0.2553 - loss: 3.0977 - val_accuracy: 0.2580 - val_loss: 3.1271
# Epoch 12/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.2729 - loss: 3.0072
# Epoch 12: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 142s 83ms/step - accuracy: 0.2729 - loss: 3.0072 - val_accuracy: 0.2590 - val_loss: 3.0749
# Epoch 13/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.2841 - loss: 2.9280
# Epoch 13: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 138s 79ms/step - accuracy: 0.2841 - loss: 2.9280 - val_accuracy: 0.2754 - val_loss: 3.0247
# Epoch 14/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.2993 - loss: 2.8467
# Epoch 14: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 81s 81ms/step - accuracy: 0.2993 - loss: 2.8467 - val_accuracy: 0.2773 - val_loss: 3.0088
# Epoch 15/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - accuracy: 0.3108 - loss: 2.7968
# Epoch 15: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 84s 83ms/step - accuracy: 0.3108 - loss: 2.7968 - val_accuracy: 0.2874 - val_loss: 2.9380
# Epoch 16/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.3260 - loss: 2.7437
# Epoch 16: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 82s 82ms/step - accuracy: 0.3260 - loss: 2.7437 - val_accuracy: 0.3000 - val_loss: 2.8963
# Epoch 17/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.3352 - loss: 2.6857
# Epoch 17: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 83s 83ms/step - accuracy: 0.3352 - loss: 2.6856 - val_accuracy: 0.2963 - val_loss: 2.9131
# Epoch 18/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.3474 - loss: 2.6338
# Epoch 18: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 143s 84ms/step - accuracy: 0.3474 - loss: 2.6338 - val_accuracy: 0.3037 - val_loss: 2.8759
# Epoch 19/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.3593 - loss: 2.5793
# Epoch 19: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 83s 83ms/step - accuracy: 0.3593 - loss: 2.5793 - val_accuracy: 0.3089 - val_loss: 2.8509
# Epoch 20/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.3660 - loss: 2.5247
# Epoch 20: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 143s 84ms/step - accuracy: 0.3660 - loss: 2.5247 - val_accuracy: 0.3179 - val_loss: 2.7732
# Epoch 21/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.3755 - loss: 2.4775
# Epoch 21: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 141s 83ms/step - accuracy: 0.3755 - loss: 2.4776 - val_accuracy: 0.3284 - val_loss: 2.7279
# Epoch 22/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.3898 - loss: 2.4231
# Epoch 22: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 138s 79ms/step - accuracy: 0.3898 - loss: 2.4231 - val_accuracy: 0.3247 - val_loss: 2.7583
# Epoch 23/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.3965 - loss: 2.3854
# Epoch 23: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 83s 80ms/step - accuracy: 0.3965 - loss: 2.3854 - val_accuracy: 0.3333 - val_loss: 2.7139
# Epoch 24/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4034 - loss: 2.3469
# Epoch 24: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 83s 82ms/step - accuracy: 0.4034 - loss: 2.3469 - val_accuracy: 0.3378 - val_loss: 2.7131
# Epoch 25/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4139 - loss: 2.3015
# Epoch 25: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 143s 83ms/step - accuracy: 0.4139 - loss: 2.3015 - val_accuracy: 0.3482 - val_loss: 2.6566
# Epoch 26/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.4265 - loss: 2.2593
# Epoch 26: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 86s 86ms/step - accuracy: 0.4265 - loss: 2.2593 - val_accuracy: 0.3506 - val_loss: 2.6424
# Epoch 27/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4308 - loss: 2.2231
# Epoch 27: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 82s 82ms/step - accuracy: 0.4308 - loss: 2.2231 - val_accuracy: 0.3474 - val_loss: 2.6443
# Epoch 28/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4407 - loss: 2.1720
# Epoch 28: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 144s 84ms/step - accuracy: 0.4407 - loss: 2.1720 - val_accuracy: 0.3564 - val_loss: 2.6227
# Epoch 29/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.4465 - loss: 2.1475
# Epoch 29: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 83s 83ms/step - accuracy: 0.4465 - loss: 2.1475 - val_accuracy: 0.3636 - val_loss: 2.6128
# Epoch 30/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4588 - loss: 2.0971
# Epoch 30: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 141s 82ms/step - accuracy: 0.4588 - loss: 2.0971 - val_accuracy: 0.3608 - val_loss: 2.6117
# Epoch 31/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4686 - loss: 2.0631
# Epoch 31: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 82s 82ms/step - accuracy: 0.4686 - loss: 2.0631 - val_accuracy: 0.3540 - val_loss: 2.6279
# Epoch 32/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4719 - loss: 2.0339
# Epoch 32: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 142s 82ms/step - accuracy: 0.4719 - loss: 2.0339 - val_accuracy: 0.3688 - val_loss: 2.5919
# Epoch 33/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.4845 - loss: 1.9886
# Epoch 33: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 144s 85ms/step - accuracy: 0.4845 - loss: 1.9887 - val_accuracy: 0.3685 - val_loss: 2.6048
# Epoch 34/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4915 - loss: 1.9634
# Epoch 34: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 84s 83ms/step - accuracy: 0.4915 - loss: 1.9634 - val_accuracy: 0.3723 - val_loss: 2.5860
# Epoch 35/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.4965 - loss: 1.9324
# Epoch 35: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 142s 84ms/step - accuracy: 0.4965 - loss: 1.9324 - val_accuracy: 0.3656 - val_loss: 2.6215
# Epoch 36/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5053 - loss: 1.8883
# Epoch 36: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 147s 89ms/step - accuracy: 0.5053 - loss: 1.8883 - val_accuracy: 0.3659 - val_loss: 2.6292
# Epoch 37/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.5171 - loss: 1.8435
# Epoch 37: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 141s 88ms/step - accuracy: 0.5171 - loss: 1.8436 - val_accuracy: 0.3698 - val_loss: 2.6213
# Epoch 38/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5224 - loss: 1.8195
# Epoch 38: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 85s 85ms/step - accuracy: 0.5224 - loss: 1.8195 - val_accuracy: 0.3698 - val_loss: 2.6308
# Epoch 39/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5251 - loss: 1.7822
# Epoch 39: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 83s 83ms/step - accuracy: 0.5251 - loss: 1.7822 - val_accuracy: 0.3702 - val_loss: 2.6364
# Epoch 40/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5364 - loss: 1.7615
# Epoch 40: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 144s 85ms/step - accuracy: 0.5364 - loss: 1.7615 - val_accuracy: 0.3744 - val_loss: 2.6462
# Epoch 41/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5402 - loss: 1.7211
# Epoch 41: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 140s 83ms/step - accuracy: 0.5402 - loss: 1.7211 - val_accuracy: 0.3696 - val_loss: 2.6895
# Epoch 42/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5558 - loss: 1.6842
# Epoch 42: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 143s 84ms/step - accuracy: 0.5558 - loss: 1.6842 - val_accuracy: 0.3732 - val_loss: 2.6704
# Epoch 43/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.5597 - loss: 1.6449
# Epoch 43: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 85s 85ms/step - accuracy: 0.5596 - loss: 1.6449 - val_accuracy: 0.3643 - val_loss: 2.7669
# Epoch 44/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5686 - loss: 1.6207
# Epoch 44: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 141s 84ms/step - accuracy: 0.5686 - loss: 1.6208 - val_accuracy: 0.3728 - val_loss: 2.6874
# Epoch 45/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.5789 - loss: 1.5824
# Epoch 45: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 142s 84ms/step - accuracy: 0.5789 - loss: 1.5825 - val_accuracy: 0.3738 - val_loss: 2.7024
# Epoch 46/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5838 - loss: 1.5431
# Epoch 46: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 144s 86ms/step - accuracy: 0.5838 - loss: 1.5431 - val_accuracy: 0.3750 - val_loss: 2.7477
# Epoch 47/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.5901 - loss: 1.5245
# Epoch 47: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 140s 84ms/step - accuracy: 0.5901 - loss: 1.5245 - val_accuracy: 0.3628 - val_loss: 2.8033
# Epoch 48/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.6014 - loss: 1.4825
# Epoch 48: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 142s 84ms/step - accuracy: 0.6014 - loss: 1.4825 - val_accuracy: 0.3667 - val_loss: 2.8244
# Epoch 49/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.6062 - loss: 1.4550
# Epoch 49: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 89s 88ms/step - accuracy: 0.6062 - loss: 1.4550 - val_accuracy: 0.3646 - val_loss: 2.8436
# Epoch 50/50
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.6175 - loss: 1.4053
# Epoch 50: saving model to /content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5
# 1000/1000 ━━━━━━━━━━━━━━━━━━━━ 139s 86ms/step - accuracy: 0.6175 - loss: 1.4053 - val_accuracy: 0.3730 - val_loss: 2.8005

# %%
# Plot the training/validation accuracy and loss
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0, 0.7])
plt.xlim([0,50])
plt.legend(loc='lower right')

# %% [markdown]
# ## Testing/Evaluation
#
# (15 points)
#
# In this section, you will write code for the following:
#
# *   Re-initialize the model
# *   Load the model weights that were saved at "/content/drive/My Drive/Colab Notebooks/cifar/" ([code reference](https://www.tensorflow.org/tutorials/keras/save_and_load))
# *   Evaluate the trained DL model on the CIFAR-100 test dataset. Accuracy value should be printed. Please visit this [website](https://benchmarks.ai/cifar-100) for the benchmark performances of different techniques on the CIFAR-100 dataset.
#
# This section of the code should be able to run independently from the **training** section, i.e. run this section directly after creating the model.

# %%
# Re-initialize the model
model = create_model()

# %%
# Load the model weights that were saved at - "/content/drive/My Drive/Colab Notebooks/cifar/"
model.load_weights("/content/drive/My Drive/Colab Notebooks/cifar/model.weights.h5")

# %%
# Evaluate the trained DL model on the CIFAR-100 test dataset
model.evaluate(test_images, test_labels)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step - accuracy: 0.3635 - loss: 2.8112
# [2.8047754764556885, 0.3610000014305115]

# %% [markdown]
# # Natural Language Processing - RNN
#
# The goal of this task is to get hands-on experience in developing, training and testing **Recurrent Neural Network** for the Natural Language Processing task of Sentiment Analysis / Text Classification. In this part, you will work with the well-known **Reuters newswire classification dataset**. The dataset consists of newswires from Reuters, labeled over 46 topics. More information about the dataset can be found [here](https://archive.ics.uci.edu/ml/datasets/reuters-21578+text+categorization+collection) or [here](https://keras.io/api/datasets/reuters/). The Keras dataset is a cleaned and organized version of the original dataset and consists of 11,228 newswires (8982 training and 2246 testing). The goal is to classify a newswire into one of the 46 output catergories.

# %% [markdown]
# ## Load/Prepare Data
#
# (15 points)
#
# In this section, you will write code for the following:
#
# *   Load the Reuters dataset - use the Keras version
#  *   Select the vocabulary size while loading the data
#  *   The data will be loaded as integer representations for each word
# *   Prepare the data to be used for the next steps
#  *   Each data entry (newswire) can be of different lengths
#  *   Make each newswire consistent - same number of words
#  *   'Pad' words (say 0) to get to the standard length or remove words

# %%
# Load the Reuters dataset - use the Keras version
#   Select the vocabulary size while loading the data
#   The data will be loaded as integer representations for each word
(x_train, y_train), (x_test, y_test) = keras.datasets.reuters.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/reuters.npz
# 2110848/2110848 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Prepare the data to be used for the next steps
#   Each data entry (newswire) can be of different lengths
#   Make each newswire consistent - same number of words
#   'Pad' words (say 0) to get to the standard length or remove words
x_train = keras.preprocessing.sequence.pad_sequences(x_train, maxlen=200)
x_test = keras.preprocessing.sequence.pad_sequences(x_test, maxlen=200)

# %% [markdown]
# ## RNN Model Creation
#
# (15 points)
#
# In this section, you will write code for the following:
#
# *   Create a DL model for Natural Language Processing - Recurrent Neural Network / LSTM / GRU
# *   Print the DL model summary

# %%
# Create a DL model for Natural Language Processing - Recurrent Neural Network / LSTM / GRU
def new_model():
  model = keras.Sequential([
                                keras.layers.Embedding(input_dim=10000, output_dim=128),
                                keras.layers.Bidirectional(keras.layers.LSTM(128, return_sequences=True)),
                                keras.layers.Bidirectional(keras.layers.LSTM(64)),
                                keras.layers.Dropout(0.5),
                                keras.layers.Dense(46, activation='softmax')
                                ])
  model.compile(
        optimizer='adam',
        loss='sparse_categorical_crossentropy',
        metrics=['accuracy']
        )
  return model

model = new_model()

# %%
# Print the DL model summary
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional (Bidirectional)        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ bidirectional_1 (Bidirectional)      │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)
# None

# %% [markdown]
# ## Training
#
# (15 points)
#
# In this section, you will write code to do the following:
#
# *   Train/fit the DL model using the training Reuters data
# *   Plot the training/validation accuracy and loss
# *   *Save the trained model weights* in a folder in the google drive at at location "/content/drive/My Drive/Colab Notebooks/reuters/" ([code reference](https://www.tensorflow.org/tutorials/keras/save_and_load)), to be used for the testing phase

# %%
# Set the model checkpoints to be saved in a folder in the google drive at at location "/content/drive/My Drive/Colab Notebooks/reuters/"
callback = keras.callbacks.ModelCheckpoint(filepath="/content/drive/My Drive/Colab Notebooks/reuters/model.weights.h5",
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
# Train/fit the DL model using the training Reuters data
history = model.fit(
    x_train, y_train,
    epochs=8,
    batch_size=50,
    validation_data=(x_test, y_test),
    callbacks=[callback]
)
# Out:
# Epoch 1/8
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4003 - loss: 2.4663
# Epoch 1: saving model to /content/drive/My Drive/Colab Notebooks/reuters/model.weights.h5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 334s 2s/step - accuracy: 0.4007 - loss: 2.4642 - val_accuracy: 0.5218 - val_loss: 1.8176
# Epoch 2/8
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5586 - loss: 1.7108
# Epoch 2: saving model to /content/drive/My Drive/Colab Notebooks/reuters/model.weights.h5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 384s 2s/step - accuracy: 0.5586 - loss: 1.7107 - val_accuracy: 0.5855 - val_loss: 1.6443
# Epoch 3/8
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6015 - loss: 1.5772
# Epoch 3: saving model to /content/drive/My Drive/Colab Notebooks/reuters/model.weights.h5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 396s 2s/step - accuracy: 0.6014 - loss: 1.5773 - val_accuracy: 0.5935 - val_loss: 1.6976
# Epoch 4/8
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6333 - loss: 1.4605
# Epoch 4: saving model to /content/drive/My Drive/Colab Notebooks/reuters/model.weights.h5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 347s 2s/step - accuracy: 0.6333 - loss: 1.4604 - val_accuracy: 0.6086 - val_loss: 1.5476
# Epoch 5/8
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6794 - loss: 1.2899
# Epoch 5: saving model to /content/drive/My Drive/Colab Notebooks/reuters/model.weights.h5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 351s 2s/step - accuracy: 0.6794 - loss: 1.2900 - val_accuracy: 0.6211 - val_loss: 1.5153
# Epoch 6/8
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7133 - loss: 1.1603
# Epoch 6: saving model to /content/drive/My Drive/Colab Notebooks/reuters/model.weights.h5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 341s 2s/step - accuracy: 0.7134 - loss: 1.1603 - val_accuracy: 0.6483 - val_loss: 1.4586
# Epoch 7/8
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7345 - loss: 1.0604
# Epoch 7: saving model to /content/drive/My Drive/Colab Notebooks/reuters/model.weights.h5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 368s 2s/step - accuracy: 0.7345 - loss: 1.0603 - val_accuracy: 0.6443 - val_loss: 1.5031
# Epoch 8/8
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7689 - loss: 0.9397
# Epoch 8: saving model to /content/drive/My Drive/Colab Notebooks/reuters/model.weights.h5
# 180/180 ━━━━━━━━━━━━━━━━━━━━ 335s 2s/step - accuracy: 0.7688 - loss: 0.9399 - val_accuracy: 0.6527 - val_loss: 1.4854

# %%
# Plot the training/validation accuracy and loss
plt.figure()
plt.title('Accuracy')
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.4, 0.8])
plt.xlim([0,10])
plt.legend(loc='lower right')
plt.show()

plt.figure()
plt.title('Loss')
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label = 'val_loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.ylim([1, 2.5])
plt.xlim([0,10])
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ## Testing/Evaluation
#
# (15 points)
#
# In this section, you will write code for the following:
#
# *   Re-initialize the model
# *   Load the model weights that were saved at "/content/drive/My Drive/Colab Notebooks/reuters/" ([code reference](https://www.tensorflow.org/tutorials/keras/save_and_load))
# *   Evaluate the trained DL model on the Reuters test dataset. Accuracy value should be printed.
#
# This section of the code should be able to run independently from the **training** section, i.e., run this section directly after creating the model.

# %%
# Re-initialize the model
model = new_model()

# %%
# Load the model weights that were saved at - "/content/drive/My Drive/Colab Notebooks/reuters/"
model.build(input_shape=(None, 200))
model.load_weights("/content/drive/My Drive/Colab Notebooks/reuters/model.weights.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:576: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 32 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# Evaluate the trained DL model on the Reuters test dataset
model.evaluate(x_test, y_test)
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 28s 372ms/step - accuracy: 0.6711 - loss: 1.4212
# [1.4854198694229126, 0.6527159214019775]

# %% [markdown]
# # Submission Instructions
#
# 1.   Complete all tasks above - **File MUST contain the output for ALL cells**
# 2.   Export this notebook as .ipynb
#       (File > Download as ipynb)
# 3.   Download and zip the folders "/content/drive/My Drive/Colab Notebooks/cifar/" (abc123_cifar_model.zip) and "/content/drive/My Drive/Colab Notebooks/reuters/" (abc123_reuters_model.zip)
# 4.   Upload the .ipynb file and .zip on Blackboard

# %% [markdown]
# ## Rubric
#
# *   Computer Vision - CNN
#     *   (20 points) Load/Prepare Data
#     *   (15 points) CNN Model Creation
#     *   (15 points) Training
#     *   (15 points) Testing/Evaluation
# *   Natural Language Processing - RNN
#     *   (15 points) Load/Prepare Data
#     *   (15 points) RNN Model Creation
#     *   (15 points) Training
#     *   (15 points) Testing/Evaluation
