# %% [markdown]
# Click Runtime -> Run All

# %%
from matplotlib import pyplot as plt
import numpy as np
import pdb # this is for debugging your code
import pandas as pd

#Question 1
# Read the data from the file fdata.csv using read_csv() and save the data in df.
# The reference of read_csv(): https://www.geeksforgeeks.org/python-read-csv-using-pandas-read_csv/
# You need to set the parameters (sep, parse_dates, index_col) in read_csv() properly
#df = pd.read_csv(XXX, sep=XXX, parse_dates=XXX, index_col=XXX)

#1. your code is here
import gdown
url = "https://drive.google.com/uc?export=download&id=1HVJS0HCtIUhpdk6wIZfeoYsy3BFhe_6b"
output = 'fdata.csv'
gdown.download(url, output, quiet=False)
df = pd.read_csv(output, sep=',', parse_dates=True, index_col=0)

# plot the figure
df.plot()
plt.show()

#Question 2
# Save the data in the variable "data"
# Each row is saved in a tuple
#data = [('2016-10-03', 772.559998), ... ]

#2. your code is here
data = [('2016-10-03',772.559998),
        ('2016-10-04',776.429993),
        ('2016-10-05',776.469971),
        ('2016-10-06',776.859985),
        ('2016-10-07',775.080017)]

# Plot the data as a red line with round markers
#3. your code is here
df = pd.DataFrame(data, columns=['Date','Num'])

# set the ticks, labels, titles, grids
#4. your code is here
plt.title("Closing stock value of Alphabet Inc.")
plt.xlabel("Date")
plt.ylabel("Closing value")

# Turn on the minor TICKS, which are required for the minor GRID
plt.minorticks_on()

# Customize the major grid
#plt.grid(which=XXX, linestyle=XXX, linewidth=XXX, color=XXX)
#5. your code is here
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
# Customize the minor grid
#6. your code is here
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.plot(df['Date'],df['Num'],'r.-')
plt.show()


#Question 3

# please save assign the data in variables
#popularity = [XXX, XXX, ...]
# 1. your code is here
language_Data =[('Java',22.2),
                ('Python',17.6),
                ('Php', 8.8),
                ('JavaScript',8),
                ('C#',7.7),
                ('C++',6.7)]

df = pd.DataFrame(language_Data, columns=['Name','Popularity'])

# plot the bar chart
# plt.XXX(XXX, XXX, color=XXX)
# 2. your code is here
plt.bar(df['Name'],df['Popularity'], color='blue')

# set ticks, labels, titles, grids
#3. your code is here
plt.title("Popularity of Programming Language \n Worldwide, Oct 2017 compared to a year ago")
plt.xlabel("Languages")
plt.ylabel("Popularity")
# Turn on the grid
#4. your code is here
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

#Question 4
# save the data in variables
#1. your code is here
language_Data =[('Java',22.2),
                ('Python',17.6),
                ('Php', 8.8),
                ('JS',8),
                ('C#',7.7),
                ('C++',6.7)]

df = pd.DataFrame(language_Data, columns=['Name','Popularity'])
plt.barh(df['Name'],df['Popularity'], color='green')

# plot the bar chart
#2. your code is here
plt.title("Popularity of Programming Language \n Worldwide, Oct 2017 compared to a year ago")
plt.xlabel("Popularity")
plt.ylabel("Languages")
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')
plt.minorticks_on()
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

#Question 5
weight1=[67,57.2,59.6,59.64,55.8,61.2,60.45,61,56.23,56]
height1=[101.7,197.6,98.3,125.1,113.7,157.7,136,148.9,125.3,114.9]
weight2=[61.9,64,62.1,64.2,62.3,65.4,62.4,61.4,62.5,63.6]
height2=[152.8,155.3,135.1,125.2,151.3,135,182.2,195.9,165.1,125.1]
weight3=[68.2,67.2,68.4,68.7,71,71.3,70.8,70,71.1,71.7]
height3=[165.8,170.9,192.8,135.4,161.4,136.1,167.1,235.1,181.1,177.3]
# your code is here to draw the scatter plot

plt.scatter(weight1,height1,marker="*",color='red')
plt.scatter(weight2,height2,marker="*",color='green')
plt.scatter(weight3,height3,marker="*",color='blue')

plt.title("Group Wise Weight vs Height")
plt.xlabel("Weight")
plt.ylabel("Height")

plt.show()
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1HVJS0HCtIUhpdk6wIZfeoYsy3BFhe_6b
# To: /content/fdata.csv
# 100%|██████████| 268/268 [00:00<00:00, 895kB/s]
# <ipython-input-42-e8027d00e345>:17: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(output, sep=',', parse_dates=True, index_col=0)
